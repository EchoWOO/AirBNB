# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

sea_data = 'Data/Seattle/'
bos_data = 'Data/Boston/'

# %% [markdown]
# ### 1. Data
# By reading in the data, we can see that the total numbers of listings in these two cities are similar, Seattle has 3818 listings, while Boston has 3585.
# <br>
# <br>
# Seattle and Boston each have three datasets:
# - Calendar: Contains the listing_id, date and price
# - listings: Includes all the details of the host, service, the house/room characteristics and summary statistics of reviews, etc.
# - reviews: Listing id, reviewer id and detailed reviews.

# %%
sea_calendar = pd.read_csv(sea_data + 'calendar.csv')
sea_listings = pd.read_csv(sea_data + 'listings.csv')
sea_reviews = pd.read_csv(sea_data + 'reviews.csv')
bos_calendar = pd.read_csv(bos_data + 'calendar.csv')
bos_listings = pd.read_csv(bos_data + 'listings.csv')
bos_reviews = pd.read_csv(bos_data + 'reviews.csv')

# %%
# transform price to numeric
sea_listings['price'] = sea_listings.price.str.replace('$','')
sea_listings['price'] = sea_listings.price.str.replace(',','')
sea_listings['price'] = pd.to_numeric(sea_listings['price'])

# %%
# transform price to numeric
bos_listings['price'] = bos_listings.price.str.replace('$','')
bos_listings['price'] = bos_listings.price.str.replace(',','')
bos_listings['price'] = pd.to_numeric(bos_listings['price'])

# %%
# Check if the ids in bos_listings are unique
bos_listings['id'].nunique() == len(bos_listings)
# Out:
# True

# %% [markdown]
# ###  2. Exploratory Analysis
# #### 2.1 Price Distribution
# Looking at all the listing prices, compare the mean, mode and range of values in Seattle and Boston

# %%
import matplotlib.style as style 
import matplotlib as mpl
# style.available[:5]    # A list of styles to choose from

# %%
sns.set_style("white")
# Could be usefule reset axes styles
# sns.axes_style()
mpl.rcParams['font.family'] = "arial narrow"
style.use('seaborn-poster')

fig, axes = plt.subplots(1, 2)

sea_listings.hist('price', bins=40, ax=axes[0], color = 'steelblue')
bos_listings.hist('price', bins=40, ax=axes[1], color = 'lightgrey')

# Add xlabels
axes[0].set(xlabel='Seattle AirBnB Price', ylabel='Percentage')
axes[1].set(xlabel='Boston AirBnB Price', ylabel='Percentage')

# Set tittle
axes[0].set_title('Seattle')
axes[1].set_title('Boston')

# Add mode
axes[0].axvline(sea_listings['price'].mode()[0], color='black', linestyle='--', alpha = 0.8, lw = 1.2)
axes[0].text(sea_listings['price'].mode()[0] + 50,400,'mode: ' + str(sea_listings['price'].mode()[0]),rotation=90)
axes[1].axvline(bos_listings['price'].mode()[0], color='black', linestyle='--', alpha = 0.8, lw = 1.2)
axes[1].text(bos_listings['price'].mode()[0] + 200,700,'mode: ' + str(bos_listings['price'].mode()[0]),rotation=90)

# Add mean
axes[0].axvline(sea_listings['price'].mean(), color='orange', linestyle='-.', alpha = 0.9, lw = 2)
axes[0].text(sea_listings['price'].mean() - 50,400,'mean: ' + str(np.round(sea_listings['price'].mean(),1)),rotation=90)
axes[1].axvline(bos_listings['price'].mean(), color='orange', linestyle='-.', alpha = 0.9, lw = 2)
axes[1].text(bos_listings['price'].mean() - 300,700,'mean: ' + str(np.round(bos_listings['price'].mean(),1)),rotation=90)
# ### 3. Data Cleaning
# Clean all features

# %%
# Categorical/numeric columns for Seattle
cat_vars = sea_listings.select_dtypes(include = ['object']).columns
num_vars = sea_listings.select_dtypes(include = ['float','int']).columns

# %%
# select the useful columns and examine if further data cleaning is needed
cat_vars_select = ['amenities', # transform to amenities type
                   'host_verifications', # transform to number of verifications
                   'host_since', 'host_response_time', 'first_review', 'last_review', # time vars
                   'security_deposit', 'cleaning_fee', 'extra_people', # convert str with $ to float 
                    
                   # variables ready to go
                   'host_neighbourhood', 'neighbourhood', 'host_acceptance_rate', 'host_response_rate',
                   'neighbourhood_cleansed', 'zipcode', 'property_type', 'room_type', 'bed_type','cancellation_policy', 

                   # boolean
                   'host_has_profile_pic', 'host_identity_verified', 'host_is_superhost',
                   'requires_license', 'is_location_exact', 
                   'instant_bookable', 'require_guest_profile_picture', 'require_guest_phone_verification']

num_vars_select = [#'host_listings_count', 'host_total_listings_count', 
                   'accommodates', 'bathrooms', 
                   'bedrooms', 'beds', 'square_feet', 'guests_included', 'minimum_nights', 'maximum_nights', 
                   'availability_30', 'availability_60', 'availability_90', 'availability_365', 
                   'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 
                   'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
                   'review_scores_value', 'calculated_host_listings_count', 'reviews_per_month']

# %%
cat_var_df = sea_listings[cat_vars_select]
num_vars_select = sea_listings[num_vars_select]

# %%
amenity_vars = ['amenities']
amenity_vars_df = cat_var_df[amenity_vars].apply(lambda col: col.replace({"\{":'','"':'','}':'',' ':''}, regex = True), axis = 0)

# convert string to list
amenity_vars_df = amenity_vars_df[amenity_vars].apply(lambda col: col.str.split(','))

# get the list into dummies
amenity_vars_df = pd.get_dummies(amenity_vars_df['amenities'].apply(pd.Series).stack()).sum(level=0)

# %%
# verification vars to dummies
veri_vars = ['host_verifications']
veri_vars_df = cat_var_df[veri_vars].apply(lambda col: col.replace({"\[":'',"'":'',']':'',' ':''}, regex = True), axis = 0)

# convert string to list
veri_vars_df = veri_vars_df[veri_vars].apply(lambda col: col.str.split(','))

# get the unique types of verifications:
# veri_vars_array = list(veri_vars_df['host_verifications'])
# veri_types = list(set(x for l in veri_vars_array for x in l))

# get the list into dummies
veri_vars_df = pd.get_dummies(veri_vars_df['host_verifications'].apply(pd.Series).stack()).sum(level=0)

# %%
# money vars: convert string to float
money_vars = ['security_deposit', 'cleaning_fee', 'extra_people']
money_vars_df = cat_var_df[money_vars]

# lambda function to remove '$',',' in dataframe
money_vars_df = money_vars_df[money_vars].apply(lambda col: col.replace({'\$':'',',':''}, regex = True).astype(float), axis = 0)

# %%
# time vars: convert string to date then number of days
time_vars = ['host_since', 'first_review', 'last_review']
time_vars_df = cat_var_df[time_vars]

# Use lambda to avoid the copy error
time_vars_df = time_vars_df[time_vars].apply(lambda col: pd.to_datetime(col), axis = 0)
# time_vars_df['day_'+'host_since'] = (pd.Timestamp.now() - time_vars_df['host_since']).dt.days

# define a function to convert 
def date_to_now(vars, df):
    ''' calulate number of days since the date to now'''
    for column_name in time_vars:
        try:
            df['day_' + column_name] = (pd.Timestamp.now() - df[column_name]).dt.days
        except:
            continue
    return df

day_vars_df = date_to_now(time_vars, time_vars_df).drop(time_vars, axis = 1)

# %%
# boolean vars: convert categorical to boolean
bool_vars = ['host_has_profile_pic', 'host_identity_verified', 'host_is_superhost',
             #'requires_license', 'is_location_exact', 
             'instant_bookable', 'require_guest_profile_picture', 'require_guest_phone_verification']

bool_vars_df = cat_var_df[bool_vars].replace({'t': True, 'f': False})

# %%
# categorical vars: categorical variables to dummy
categorical_vars = [#'host_neighbourhood', 'neighbourhood', 'neighbourhood_cleansed', 
                    'host_acceptance_rate', 'host_response_time',
                    'zipcode', 'property_type', 'room_type', 'bed_type',
                    'cancellation_policy','host_response_rate']

categorical_vars_df = cat_var_df[categorical_vars]

# %%
cleaned_sea_listing = pd.concat([amenity_vars_df, money_vars_df, #veri_vars_df, 
                                 day_vars_df, bool_vars_df, categorical_vars_df,
                                 num_vars_select, sea_listings['price']], axis=1)
cleaned_sea_listing = cleaned_sea_listing.dropna(subset = ['price'], axis = 0)

# %% [markdown]
# ### 4. Interesting features
# Explore the relationship between features and list pricings.
# #### 4.1 Room type and listing price

# %%
type_vars =  ['property_type','room_type']
sea_type_df = sea_listings[type_vars]
bos_type_df = bos_listings[type_vars]
# .apply(lambda col: col.replace({"\{":'','"':'','}':'',' ':''}, regex = True), axis = 0)

# combine with price column
sea_type_price = pd.concat([sea_type_df, sea_listings['price']], axis = 1).dropna(subset = ['price'], axis = 0)
sea_type_price['city'] = 'Seattle'
bos_type_price = pd.concat([bos_type_df, bos_listings['price']], axis = 1).dropna(subset = ['price'], axis = 0)
bos_type_price['city'] = 'Boston'

# %%
type_price = sea_type_price.append(bos_type_price)
type_price.head()
# Out:
#   property_type        room_type  price     city
# 0     Apartment  Entire home/apt   85.0  Seattle
# 1     Apartment  Entire home/apt  150.0  Seattle
# 2         House  Entire home/apt  975.0  Seattle
# 3     Apartment  Entire home/apt  100.0  Seattle
# 4         House  Entire home/apt  450.0  Seattle

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Violin(x=type_price['room_type'][type_price['city'] == 'Seattle' ],
                        y=type_price['price'][type_price['city'] == 'Seattle' ],
                        legendgroup='Seattle', scalegroup='Seattle', name='Seattle',
                        line_color='blue')
             )
fig.add_trace(go.Violin(x=type_price['room_type'][type_price['city'] == 'Boston' ],
                        y=type_price['price'][type_price['city'] == 'Boston' ],
                        legendgroup='Boston', scalegroup='Boston', name='Boston',
                        line_color='orange')
             )

fig.update_traces(box_visible=True, meanline_visible=True)
fig.update_layout(violinmode='group')
fig.show()
# Out:
# <div>
#
#
#             <div id="4c87df3a-3d80-49be-a6ec-9521df999a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c87df3a-3d80-49be-a6ec-9521df999a1b")) {
#                     Plotly.newPlot(
#                         '4c87df3a-3d80-49be-a6ec-9521df999a1b',
#                         [{"box": {"visible": true}, "legendgroup": "Seattle", "line": {"color": "blue"}, "meanline": {"visible": true}, "name": "Seattle", "scalegroup": "Seattle", "type": "violin", "x": ["Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Shared room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Enti ...

# %% [markdown]
# #### 4.2 House type and listing price

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Violin(x=type_price['property_type'][type_price['city'] == 'Seattle' ],
                        y=type_price['price'][type_price['city'] == 'Seattle' ],
                        legendgroup='Seattle', scalegroup='Seattle', name='Seattle',
                        line_color='blue')
             )
fig.add_trace(go.Violin(x=type_price['property_type'][type_price['city'] == 'Boston' ],
                        y=type_price['price'][type_price['city'] == 'Boston' ],
                        legendgroup='Boston', scalegroup='Boston', name='Boston',
                        line_color='orange')
             )

fig.update_traces(box_visible=True, meanline_visible=True)
fig.update_layout(violinmode='group')
fig.show()
# Out:
# <div>
#
#
#             <div id="e1e4862e-c808-42c3-8704-0eaeee8c21e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1e4862e-c808-42c3-8704-0eaeee8c21e5")) {
#                     Plotly.newPlot(
#                         'e1e4862e-c808-42c3-8704-0eaeee8c21e5',
#                         [{"box": {"visible": true}, "legendgroup": "Seattle", "line": {"color": "blue"}, "meanline": {"visible": true}, "name": "Seattle", "scalegroup": "Seattle", "type": "violin", "x": ["Apartment", "Apartment", "House", "Apartment", "House", "House", "House", "Cabin", "Apartment", "Apartment", "House", "House", "Apartment", "House", "House", "House", "Apartment", "House", "Apartment", "House", "Condominium", "House", "House", "House", "House", "House", "House", "Camper/RV", "Apartment", "Apartment", "Apartment", "House", "House", "House", "Apartment", "Apartment", "House", "House", "Apartment", "Apartment", "Apartment", "House", "House", "Apartment", "House", "Apartment", "Bungalow", "Bungalow", "House", "House", "House", "Apartment", "Apartment", "Apartment", "Townhouse", "Apartment", "Townhouse", "House", "House", "House", "Apartment", "Apartment", "House", "Camper/RV", "House", "House", "Apartment", "House", "Apartment", "Condominium", "Apartment", "House", "Apartment", "House", "House", "House", "House", "House", "House", "House", "House", "House", "Apartment", "House", "Apartment", "Apartment", "Apartment", "Townhouse", "Apartment", "Apartment", "Bungalow", "House", "House", "Apartment", "Apartment", "Apartment", "Cabin", "House", "House", "Apartment", "Apartment", "House", "House", "House", "Condominium", "Apartment", "House", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Townhouse", "House", "Apartment", "Apartment", "Apartment", "Townhouse", "House", "House", "Apartment", "House", "House", "House", "House", "House", "House", "Townhouse", "House", "Loft", "House", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Apartment", "House", "House", "House", "House", "House", "House", "House", "House", "House", "House", "House", "Townhouse", "House", "House", "Apartment", "Apartment", "House", "Apartment", "House", "Apartment", "Townhouse", "House", "House", "Apartment", "House", "Apartment", "House", "House", "House", "House", "Apartment", "House", "Apartment", "Apartment", "House", "House", "Apartment", "House", "Apartment", "House", "Camper/RV", "Apartment", "House", "House", "Apartment", "House", "House", "House", "House", "House", "Townhouse", "House", "Apartment", "House", "House", "House", "House", "House", "House", "House", "Townhouse", "House", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Boat", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Apartment", "Condominium", "Apartment", "House", "Apartment", "Apartment", "House", "Apartment", "Apartment", "House", "House", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "House", "Condominium", "Apartment", "Apartment", "Apartment", "House", "House", "Condominium", "Apartment", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "House", "Apartment", "Apartment", "House", "Apartment", "House", "House", "Apartment", "House", "House", "House", "Bungalow", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Loft", "Apartment", "Apartment", "Apartment", "House", "House", "Apartment", "Loft", "Apartment", "Apartment", "House", "House", "House", "House", "Apartment", "Apartment", "House", "House", "House", "Apartment", "Apartment", "House", "House", "House", "Apartment", "House", "Apartment", "House", "Apartment", "Apartment", "House", "House", "Apartment", "House", "House", "House", "House", "Apartment", "Apartment", "House", "Apartment", "Apartment", "Apartment", "Boat", "House", "House", "Apartment", "Apartment", "House", "House", "Apartment", "House", "House", "Apartment", "Apartment", "House", "House", "House", "House", "House", "Apartment", "Apartment", "House", "House", "House", "Apartment", "House", "House", "House", "Hou ...

# %% [markdown]
# ### 5. Modeling
# Fill numerica variable NAs with mean, transform categorical variable to dummies. Train, fit and predict using linear regression.

# %%
# fill the numeric variables with mean
numeric_vars = cleaned_sea_listing.select_dtypes(include = ['float','int']).columns

cleaned_sea_listing[numeric_vars] = cleaned_sea_listing[numeric_vars].\
                                    apply(lambda col: col.fillna(col.mean()),axis = 0)

# %%
# Dummy the categorical variables
categorical_vars = cleaned_sea_listing.select_dtypes(include = ['object']).copy().columns

for var in  categorical_vars:
    # for each cat add dummy var, drop original column
    cleaned_sea_listing = pd.concat([cleaned_sea_listing.drop(var, axis=1), 
                                     pd.get_dummies(cleaned_sea_listing[var], prefix=var, 
                                                    prefix_sep='_', drop_first=True)], axis=1)

# %%
X = cleaned_sea_listing.drop('price', axis = 1)
y = cleaned_sea_listing['price']

# %%
# Split X y train test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10) 
# Instantiate model
lm_model = LinearRegression(normalize = True)
# Fit training
lm_model.fit(X_train, y_train)
# predict test data
y_test_pred = lm_model.predict(X_test)
# predict training data
y_train_pred = lm_model.predict(X_train)
# score the model on train and test
print(r2_score(y_test, y_test_pred), r2_score(y_train, y_train_pred))
# Out:
# 0.6873169485325695 0.6295842919964003

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                        est_int       coefs   abs_coefs
# 108         property_type_Boat  129.795823  129.795823
# 114         property_type_Dorm -103.163278  103.163278
# 103              zipcode_98177  -68.660955   68.660955
# 123      room_type_Shared room  -68.148876   68.148876
# 98               zipcode_98133  -57.087573   57.087573
# 142     host_response_rate_57%   53.200026   53.200026
# 73   host_has_profile_pic_True  -53.060310   53.060310
# 84               zipcode_98106  -52.317925   52.317925
# 96               zipcode_98125  -47.986486   47.986486
# 130     host_response_rate_17%   45.094690   45.094690
# 92               zipcode_98118  -44.893044   44.893044
# 111    property_type_Camper/RV   42.378979   42.378979
# 86               zipcode_98108  -41.911860   41.911860
# 145     host_response_rate_63%  -41.874113   41.874113
# 120    property_type_Treehouse   41.650274   41.650274
# 102              zipcode_98146  -38.522998   38.522998
# 101              zipcode_98144  -38.217332   38.217332
# 165     host_response_rate_91%  -37.835499   37.835499
# 104              zipcode_98178  -37.007999   37.007999
# 106          zipcode_99\n98122  -36.539435   36.539435

# %%
sns.set_style("white")
# Could be usefule reset axes styles
# sns.axes_style()
mpl.rcParams['font.family'] = "arial narrow"
style.use('seaborn-poster')

# plot residuals
plt.scatter(y_train_pred,  y_train_pred - y_train,
            c='blue', marker='o', s = 1, label='Training data')
plt.scatter(y_test_pred,  y_test_pred - y_test,
            c='red', marker='s', s = 2, label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 6. Appendix
#
# #### Other logging business questions
#
# Business questions Comparing AirBnB in Seattle and Boston:
# - Is the price keeping increasing?
# - Predicting the listing price: Which matters the most? The characteristics of houses or location?
# - How many reviewers are hosts as well?
# - How people would like to name their AirBnBs? What are the popular words appeared in the most popular houses?
# - Which price range is the most popular generally?
#
# - __Price distribution/ Which neighborhood has the highest price?__
# - __Which is more expensive?__
# - __What is the most important predictor of the house price? (correlation matrix)__
# - what you can do to get a higher price on AirBNB?

# %% [markdown]
# #### Other Data Cleaning
# Listing availability in a year

# %%
# Merge listings with calendar
sea_listing_available = pd.merge(sea_listings[['id', 'name']],
                                 sea_calendar,
                                 left_on = 'id', 
                                 right_on = 'listing_id',
                                 how = 'right')

# %%
# Convert data format
sea_listing_available['date'] = pd.to_datetime(sea_listing_available['date'])
sea_listing_available['available'] = np.where(sea_listing_available['available'] == 't', True, False)

# Then check data format
sea_listing_available.dtypes
# Out:
# id                     int64
# name                  object
# listing_id             int64
# date          datetime64[ns]
# available               bool
# price                 object
# dtype: object

# %%
# group by availability on each day and count
sea_available_sum = pd.DataFrame(sea_listing_available.groupby(['id','available'])['listing_id'].\
                                 agg('count')).reset_index()

# rename column names
sea_available_sum.rename(columns = {'id':'id', 'available':'available','listing_id':'Count'}, \
                         inplace = True)
sea_available_sum.head()
# Out:
#      id  available  Count
# 0  3335      False     56
# 1  3335       True    309
# 2  4291       True    365
# 3  5682      False     56
# 4  5682       True    309

# %%
# Filter only the available days
sea_available_pct = sea_available_sum[sea_available_sum['available']==True].copy()

# Calculate percentage of occupied/unavailable in a 
sea_available_pct['available_pct'] = np.round(sea_available_pct['Count']/365, decimals = 3)

# %%
sea_available_pct.head()
# Out:
#      id  available  Count  available_pct
# 1  3335       True    309          0.847
# 2  4291       True    365          1.000
# 4  5682       True    309          0.847
# 5  6606       True    365          1.000
# 7  7369       True     53          0.145
